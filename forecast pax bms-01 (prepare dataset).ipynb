# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %% [markdown]
# ## Read Data

# %% [markdown]
# ### Read Data April

# %%
data_april = pd.read_excel('Data Transaksi April 2023.xlsx')
data_april
# Out:
#          id_seq  booking_id                        route_info   price
# 0       6696849     5327121  Bandung (Caringin - Batununggal)  170000  \
# 1       6696850     5327122  Bandung (Caringin - Batununggal)  170000
# 2       6696851     5327123         Bekasi Barat - Kayuringin  100000
# 3       6696852     5327124         Bekasi Barat - Kayuringin  100000
# 4       6696853     5327125         Bekasi Barat - Kayuringin  100000
# ...         ...         ...                               ...     ...
# 115710  6812564     5423355  Bandung (Caringin - Batununggal)  170000
# 115711  6812565     5423356  Bandung (Caringin - Batununggal)  170000
# 115712  6812566     5423356  Bandung (Caringin - Batununggal)  170000
# 115713  6812567     5423356  Bandung (Caringin - Batununggal)  170000
# 115714  6812568     5423357  Bandung (Caringin - Batununggal)  170000
#
#         shelter_id created_by          created_on
# 0                4   kiosk.t2 2023-04-01 00:30:46
# ...

# %%
data_april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115715 entries, 0 to 115714
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_seq      115715 non-null  int64
#  1   booking_id  115715 non-null  int64
#  2   route_info  115715 non-null  object
#  3   price       115715 non-null  int64
#  4   shelter_id  115715 non-null  int64
#  5   created_by  115641 non-null  object
#  6   created_on  115715 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# ### Read Data Mei

# %%
data_mei = pd.read_excel('Data Transaksi Mei 2023.xlsx')
data_mei
# Out:
#          id_seq  booking_id                        route_info   price
# 0       6812569     5423358  Bandung (Caringin - Batununggal)  170000  \
# 1       6812570     5423359  Bandung (Caringin - Batununggal)  170000
# 2       6812571     5423360  Bandung (Caringin - Batununggal)  170000
# 3       6812572     5423361  Bandung (Caringin - Batununggal)  170000
# 4       6812573     5423361  Bandung (Caringin - Batununggal)  170000
# ...         ...         ...                               ...     ...
# 147537  6960106     5548495  Bandung (Caringin - Batununggal)  170000
# 147538  6960107     5548495  Bandung (Caringin - Batununggal)  170000
# 147539  6960108     5548495  Bandung (Caringin - Batununggal)  170000
# 147540  6960109     5548496  Bandung (Caringin - Batununggal)  170000
# 147541  6960110     5548497  Bandung (Caringin - Batununggal)  170000
#
#         shelter_id created_by          created_on
# 0                1   kiosk.t1 2023-05-01 00:04:19
# ...

# %%
data_mei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147542 entries, 0 to 147541
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_seq      147542 non-null  int64
#  1   booking_id  147542 non-null  int64
#  2   route_info  147542 non-null  object
#  3   price       147542 non-null  int64
#  4   shelter_id  147542 non-null  int64
#  5   created_by  147542 non-null  object
#  6   created_on  147542 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 7.9+ MB

# %% [markdown]
# ### Read Data Juni

# %%
data_juni = pd.read_excel('Data Transaksi Juni 2023.xlsx')
data_juni
# Out:
#          id_seq  booking_id                        route_info   price
# 0       6960111     5548498  Bandung (Caringin - Batununggal)  170000  \
# 1       6960112     5548499  Bandung (Caringin - Batununggal)  170000
# 2       6960113     5548500  Bandung (Caringin - Batununggal)  170000
# 3       6960114     5548500  Bandung (Caringin - Batununggal)  170000
# 4       6960115     5548501  Bandung (Caringin - Batununggal)  170000
# ...         ...         ...                               ...     ...
# 118582  7078693     5649206  Bandung (Caringin - Batununggal)  170000
# 118583  7078694     5649206  Bandung (Caringin - Batununggal)  170000
# 118584  7078695     5649206  Bandung (Caringin - Batununggal)  170000
# 118585  7078696     5649206  Bandung (Caringin - Batununggal)  170000
# 118586  7078697     5649207  Bandung (Caringin - Batununggal)  170000
#
#         shelter_id created_by          created_on
# 0                4   kiosk.t2 2023-06-01 00:12:39
# ...

# %%
data_juni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118587 entries, 0 to 118586
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_seq      118587 non-null  int64
#  1   booking_id  118587 non-null  int64
#  2   route_info  118587 non-null  object
#  3   price       118587 non-null  int64
#  4   shelter_id  118587 non-null  int64
#  5   created_by  118587 non-null  object
#  6   created_on  118587 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 6.3+ MB

# %% [markdown]
# ### Read Data Juli

# %%
data_juli = pd.read_excel('Data Transaksi 1 - 20 Juli 2023.xlsx')
data_juli
# Out:
#         id_seq  booking_id                        route_info   price
# 0      7078698     5649208  Bandung (Caringin - Batununggal)  170000  \
# 1      7078699     5649209  Bandung (Caringin - Batununggal)  170000
# 2      7078700     5649210                    Stasiun Gambir   80000
# 3      7078701     5649211                        Purwakarta  170000
# 4      7078702     5649211                        Purwakarta  170000
# ...        ...         ...                               ...     ...
# 72875  7151573     5710051  Bandung (Caringin - Batununggal)  170000
# 72876  7151574     5710052                Mall Kelapa Gading   80000
# 72877  7151575     5710053                    Stasiun Gambir   80000
# 72878  7151576     5710053                    Stasiun Gambir   80000
# 72879  7151577     5710054      Bogor Botani - Baranangsiang  130000
#
#        shelter_id created_by          created_on
# 0               5   kiosk.t3 2023-07-01 00:39:09
# ...

# %%
data_juli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72880 entries, 0 to 72879
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_seq      72880 non-null  int64
#  1   booking_id  72880 non-null  int64
#  2   route_info  72880 non-null  object
#  3   price       72880 non-null  int64
#  4   shelter_id  72880 non-null  int64
#  5   created_by  72880 non-null  object
#  6   created_on  72880 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Combine Data

# %%
frames = [data_april, data_mei, data_juni, data_juli]
combine_data = pd.concat(frames)

# %%
df = combine_data[['id_seq', 'route_info', 'shelter_id', 'created_on']]
df
# Out:
#         id_seq                        route_info  shelter_id
# 0      6696849  Bandung (Caringin - Batununggal)           4  \
# 1      6696850  Bandung (Caringin - Batununggal)           4
# 2      6696851         Bekasi Barat - Kayuringin           4
# 3      6696852         Bekasi Barat - Kayuringin           4
# 4      6696853         Bekasi Barat - Kayuringin           4
# ...        ...                               ...         ...
# 72875  7151573  Bandung (Caringin - Batununggal)           4
# 72876  7151574                Mall Kelapa Gading           5
# 72877  7151575                    Stasiun Gambir           4
# 72878  7151576                    Stasiun Gambir           4
# 72879  7151577      Bogor Botani - Baranangsiang           5
#
#                created_on
# 0     2023-04-01 00:30:46
# 1     2023-04-01 00:33:53
# 2     2023-04-01 00:34:44
# 3     2023-04-01 00:36:42
# 4     2023-04-01 00:37:48
# ...                   ...
# 72875 2023-07-20 10:32:12
# ...

# %%
df = df[df.route_info != 'RUTE_TESTING']
df
# Out:
#         id_seq                        route_info  shelter_id
# 0      6696849  Bandung (Caringin - Batununggal)           4  \
# 1      6696850  Bandung (Caringin - Batununggal)           4
# 2      6696851         Bekasi Barat - Kayuringin           4
# 3      6696852         Bekasi Barat - Kayuringin           4
# 4      6696853         Bekasi Barat - Kayuringin           4
# ...        ...                               ...         ...
# 72875  7151573  Bandung (Caringin - Batununggal)           4
# 72876  7151574                Mall Kelapa Gading           5
# 72877  7151575                    Stasiun Gambir           4
# 72878  7151576                    Stasiun Gambir           4
# 72879  7151577      Bogor Botani - Baranangsiang           5
#
#                created_on
# 0     2023-04-01 00:30:46
# 1     2023-04-01 00:33:53
# 2     2023-04-01 00:34:44
# 3     2023-04-01 00:36:42
# 4     2023-04-01 00:37:48
# ...                   ...
# 72875 2023-07-20 10:32:12
# ...

# %% [markdown]
# ### Create shelter name column

# %%
shelter_name = []
for i in range(len(df)):
    if df['shelter_id'].values[i] == 1:
        shelter_name.append('T1')
    elif df['shelter_id'].values[i] == 4:
        shelter_name.append('T2')
    elif df['shelter_id'].values[i] == 5:
        shelter_name.append('T3')
print(len(shelter_name))
# Out:
# 454482

# %%
df['shelter_name'] = shelter_name
df
# Out:
# C:\Users\farid\AppData\Local\Temp\ipykernel_6236\1196614976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['shelter_name'] = shelter_name
#         id_seq                        route_info  shelter_id
# 0      6696849  Bandung (Caringin - Batununggal)           4  \
# 1      6696850  Bandung (Caringin - Batununggal)           4
# 2      6696851         Bekasi Barat - Kayuringin           4
# 3      6696852         Bekasi Barat - Kayuringin           4
# 4      6696853         Bekasi Barat - Kayuringin           4
# ...        ...                               ...         ...
# 72875  7151573  Bandung (Caringin - Batununggal)           4
# 72876  7151574                Mall Kelapa Gading           5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 454482 entries, 0 to 72879
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id_seq        454482 non-null  int64
#  1   route_info    454482 non-null  object
#  2   shelter_id    454482 non-null  int64
#  3   created_on    454482 non-null  datetime64[ns]
#  4   shelter_name  454482 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 20.8+ MB

# %% [markdown]
# ## Create Hourly Data

# %%
start = datetime.datetime(2023, 4, 1)
end = datetime.datetime(2023, 7, 20)
step = datetime.timedelta(hours=1)

date = []

while start <= end:
    date.append(start.strftime('%Y-%m-%d %H:%M:%S'))
    start += step
date = pd.to_datetime(pd.Series(date), format='%Y-%m-%d %H:%M:%S')

date_time = []
for i in range(len(date[:])):
    date_time.append(date[i].strftime("%Y-%m-%d %H:%M:%S"))
print(date_time[:5]);print(date_time[-5:])
print(len(date_time))
# Out:
# ['2023-04-01 00:00:00', '2023-04-01 01:00:00', '2023-04-01 02:00:00', '2023-04-01 03:00:00', '2023-04-01 04:00:00']
# ['2023-07-19 20:00:00', '2023-07-19 21:00:00', '2023-07-19 22:00:00', '2023-07-19 23:00:00', '2023-07-20 00:00:00']
# 2641

# %%
def get_pax_bms(terminal):
    num_pax = []
    for i in range(len(date_time[:-1])):
        time2 = datetime.datetime.strptime(str(date_time[i+1]), '%Y-%m-%d %H:%M:%S') - datetime.timedelta(minutes=1)
        temp = df[df['created_on'] > date_time[i]]
        temp = temp[temp['created_on'] < time2]
        temp_ = temp[temp['shelter_name'] == f'T{terminal}']
        num_pax.append(len(temp_))
    print(f'length data pax bms terminal {terminal}:',len(num_pax))
    return(num_pax)

# %%
pax_bms_t1 = get_pax_bms(terminal=1)
pax_bms_t2 = get_pax_bms(terminal=2)
pax_bms_t3 = get_pax_bms(terminal=3)
# Out:
# length data pax bms terminal 1: 2640
# length data pax bms terminal 2: 2640
# length data pax bms terminal 3: 2640

# %%
data_bms = pd.DataFrame()
data_bms["DATE"] = pd.to_datetime(date_time[:-1], errors = 'coerce')
data_bms["PAX_BMS_T1"] = pax_bms_t1
data_bms["PAX_BMS_T2"] = pax_bms_t2
data_bms["PAX_BMS_T3"] = pax_bms_t3

data_bms
# Out:
#                     DATE  PAX_BMS_T1  PAX_BMS_T2  PAX_BMS_T3
# 0    2023-04-01 00:00:00           0           8           0
# 1    2023-04-01 01:00:00           0           0           0
# 2    2023-04-01 02:00:00           0           0           0
# 3    2023-04-01 03:00:00           0           0           0
# 4    2023-04-01 04:00:00           0           0           0
# ...                  ...         ...         ...         ...
# 2635 2023-07-19 19:00:00          73         119          65
# 2636 2023-07-19 20:00:00          69          92          90
# 2637 2023-07-19 21:00:00          28          25          47
# 2638 2023-07-19 22:00:00           2           9          31
# 2639 2023-07-19 23:00:00           1           3           4
#
# [2640 rows x 4 columns]

# %% [markdown]
# ## Visualisasi Data

# %%
plt.subplots(figsize=(25, 5))
ax = sns.lineplot(x="DATE", y="PAX_BMS_T1", data=data_bms, 
                    label="Pax BMS T1", marker='.', color='deepskyblue')
plt.xlabel('Waktu'); plt.ylabel('Jumlah Penumpang')
plt.title("Data Jumlah Pax BMS per Terminal 1 CGK\nPada 1 April - 19 Juli 2023\n", fontsize = 15)
plt.grid()
plt.legend(loc='upper left')

# %%
plt.subplots(figsize=(25, 5))
ax = sns.lineplot(x="DATE", y="PAX_BMS_T2", data=data_bms, 
                    label="Pax BMS T2", marker='.', color='darkorange')
plt.xlabel('Waktu'); plt.ylabel('Jumlah Penumpang')
plt.title("Data Jumlah Pax BMS per Terminal 2 CGK\nPada 1 April - 19 Juli 2023\n", fontsize = 15)
plt.grid()
plt.legend(loc='upper left')

# %%
plt.subplots(figsize=(25, 5))
ax = sns.lineplot(x="DATE", y="PAX_BMS_T3", data=data_bms, 
                    label="Pax BMS T3", marker='.', color='seagreen')
plt.xlabel('Waktu'); plt.ylabel('Jumlah Penumpang')
plt.title("Data Jumlah Pax BMS per Terminal 3 CGK\nPada 1 April - 19 Juli 2023\n", fontsize = 15)
plt.grid()
plt.legend(loc='upper left')

# %%
plt.subplots(figsize=(25, 5))
ax = sns.lineplot(x="DATE", y="PAX_BMS_T1", data=data_bms, 
                    label="Pax BMS T1", color='deepskyblue')
ax = sns.lineplot(x="DATE", y="PAX_BMS_T2", data=data_bms, 
                    label="Pax BMS T2",color='darkorange')
ax = sns.lineplot(x="DATE", y="PAX_BMS_T3", data=data_bms, 
                    label="Pax BMS T3", color='seagreen')
plt.xlabel('Waktu'); plt.ylabel('Jumlah Penumpang')
plt.title("Data Jumlah Pax BMS per Terminal CGK\nPada 1 April - 19 Juli 2023\n", fontsize = 15)
plt.grid()
plt.legend(loc='upper left')

# %% [markdown]
# ## Export Data

# %%
# data_bms.to_excel('ready_data_pax_bms 1 April - 19 Juli 2023.xlsx')
